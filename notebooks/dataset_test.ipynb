# %%
import sys
from pathlib import Path
import os

sys.path.append("../")

# %%
from src.common import tools

config = tools.load_config()

# %%
#from src.data import download

#data_path = Path("../data")

#download.kaggle_download_data(config["stockfish_dataset_handle"], data_path, config["stockfish_dataset_name"])

# %%
from src.preprocess import datasets

dataset = datasets.ChessDataset(Path("../data/stockfish-best-moves-compilation/dataset_eval.csv"))

dataset[0]
# Out:
# rnbqkbnr/pppppppp/8/8/4P3/8/PPPP1PPP/RNBQKBNR b KQkq - 0 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[4], line 5
#       1 from src.preprocess import datasets
#       3 dataset = datasets.ChessDataset(Path("../data/stockfish-best-moves-compilation/dataset_eval.csv"))
# ----> 5 dataset[0]
#
# File ~/git/checkers/notebooks/../src/preprocess/datasets.py:22, in ChessDataset.__getitem__(self, index)
#      19 def __getitem__(self, index):
#      20     position, best_move, evaluation = self.samples[index]
# ---> 22     decoded_position = tools.decode_fen_pos(position)
#      23     normalized_evaluation = tanh(evaluation)  # Normalize to [-1, 1]
#      25     return decoded_position, best_move, normalized_evaluation
#
# File ~/git/checkers/notebooks/../src/common/tools.py:99, in decode_fen_pos(fen)
#      97     col_idx += int(char)  # Skip empty squares
# ...
